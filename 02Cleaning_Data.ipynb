# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('../Data/Raw_Data/airbnb_dataset.csv')
df.head()
# Out:
#    listing_id  host_id host_name  neighbourhood           city  \
# 0      107345    10276       NaN          Bronx  New York City
# 1      109454     5049      Emma     Manhattan             NYC
# 2      119857    11567    Sophia     Manhattan             NYC
# 3      108591     5546       NaN         Queens            NYC
# 4      117164     8693   Michael  Staten Island       New York
#
#          room_type property_type   price  minimum_nights  number_of_reviews  \
# 0       Hotel room     apartment  213.62              27                 51
# 1     Private Room   Guest suite     289              15                 38
# 2     Private room           NaN  130.82              24                 39
# 3  Entire home/apt     Apartment   36.43              13                 49
# 4  entire home/apt          Loft  271.74              21                 41
#
#    ...  beds  bedrooms  bathrooms  guests instant_bookable  \
# 0  ...   NaN      -1.0     1 bath     8.0                T
# ...

# %%
df.shape
# Out:
# (20120, 27)

# %%
Cleaned_df = df.copy()

# %%
Cleaned_df=Cleaned_df.drop_duplicates()

# %%
Cleaned_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
Cleaned_df.columns = (
    Cleaned_df.columns
    .str.strip()
    .str.lower()
    .str.replace(" ","_")
)

# %%
df.columns
# Out:
# Index(['listing_id', 'host_id', 'host_name', 'neighbourhood', 'city',
#        'room_type', 'property_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month', 'availability_365',
#        'latitude', 'longitude', 'host_since', 'last_review', 'rating', 'beds',
#        'bedrooms', 'bathrooms', 'guests', 'instant_bookable',
#        'cancellation_policy', 'host_response_rate', 'listing_status', 'device',
#        'payment_method'],
#       dtype='str')

# %%
Cleaned_df['price'] = pd.to_numeric(
    Cleaned_df['price'],errors ='coerce'
)

# %%
Cleaned_df['bathrooms'] = pd.to_numeric(
    Cleaned_df['bathrooms'],errors ='coerce'
)

# %%
df.head()
# Out:
#    listing_id  host_id host_name  neighbourhood           city  \
# 0      107345    10276       NaN          Bronx  New York City
# 1      109454     5049      Emma     Manhattan             NYC
# 2      119857    11567    Sophia     Manhattan             NYC
# 3      108591     5546       NaN         Queens            NYC
# 4      117164     8693   Michael  Staten Island       New York
#
#          room_type property_type   price  minimum_nights  number_of_reviews  \
# 0       Hotel room     apartment  213.62              27                 51
# 1     Private Room   Guest suite     289              15                 38
# 2     Private room           NaN  130.82              24                 39
# 3  Entire home/apt     Apartment   36.43              13                 49
# 4  entire home/apt          Loft  271.74              21                 41
#
#    ...  beds  bedrooms  bathrooms  guests instant_bookable  \
# 0  ...   NaN      -1.0     1 bath     8.0                T
# ...

# %%
Cleaned_df['host_response_rate'] = (
    Cleaned_df['host_response_rate']
    .astype(str)
    .str.replace('%','',regex=False)
)
Cleaned_df['host_response_rate'] = pd.to_numeric(Cleaned_df['host_response_rate'],errors = 'coerce')

# %%
df.head()
# Out:
#    listing_id  host_id host_name  neighbourhood           city  \
# 0      107345    10276       NaN          Bronx  New York City
# 1      109454     5049      Emma     Manhattan             NYC
# 2      119857    11567    Sophia     Manhattan             NYC
# 3      108591     5546       NaN         Queens            NYC
# 4      117164     8693   Michael  Staten Island       New York
#
#          room_type property_type   price  minimum_nights  number_of_reviews  \
# 0       Hotel room     apartment  213.62              27                 51
# 1     Private Room   Guest suite     289              15                 38
# 2     Private room           NaN  130.82              24                 39
# 3  Entire home/apt     Apartment   36.43              13                 49
# 4  entire home/apt          Loft  271.74              21                 41
#
#    ...  beds  bedrooms  bathrooms  guests instant_bookable  \
# 0  ...   NaN      -1.0     1 bath     8.0                T
# ...

# %%
df.tail()
# Out:
#        listing_id  host_id   host_name  neighbourhood       city  \
# 20115      111285    11257      Sophia       Brooklyn   New York
# 20116      111965     8929       David          Bronx  New York
# 20117      105391    10739     Michael  Staten Island  New York
# 20118      100861     8325  John Smith       Brooklyn        NYC
# 20119      115796     5659         NaN         Queens        NYC
#
#              room_type property_type   price  minimum_nights  \
# 20115      Shared room     Townhouse   68.76             365
# 20116     Private Room   Guest suite   69.01              19
# 20117  entire home/apt     apartment  280.07              12
# 20118      Shared room           NaN  476.49             365
# 20119     Private Room     Townhouse   84.16            3650
#
#        number_of_reviews  ...  beds  bedrooms  bathrooms  guests  \
# 20115                 44  ...   1.0       1.0    3 baths     1.0
# 20116                 30  ...   NaN       5.0     1 bath     6.0
# ...

# %%
(Cleaned_df['host_response_rate'].dtype)
# Out:
# dtype('float64')

# %%
Cleaned_df['host_response_rate'].head(20)
# Out:
# 0       NaN
# 1      80.0
# 2       NaN
# 3     100.0
# 4      85.0
# 5      80.0
# 6      80.0
# 7      80.0
# 8       NaN
# 9      95.0
# 10     85.0
# 11      NaN
# 12      NaN
# 13      NaN
# 14     95.0
# 15    100.0
# 16     85.0
# 17     85.0
# 18     80.0
# 19     80.0
# Name: host_response_rate, dtype: float64

# %%
Cleaned_df['host_since'] = pd.to_datetime(Cleaned_df['host_since'],errors = "coerce")

# %%
Cleaned_df['last_review'] = pd.to_datetime(Cleaned_df['last_review'],errors = 'coerce')

# %%
pd.set_option('display.max_columns',None)

# %%
Categorical_columns = [
    'neighbourhood',
    'city',
    'room_type',
    'property_type',
    'instant_bookable',
    'cancellation_policy',
    'listing_status',
    'device',
    'payment_method'
]

# %%
for col in Categorical_columns:
    Cleaned_df[col] = Cleaned_df[col].str.strip().str.lower()

# %%
Cleaned_df.isnull().sum().sort_values(ascending = False)
# Out:
# bathrooms              13330
# host_name               3605
# bedrooms                3394
# payment_method          3356
# device                  3319
# host_response_rate      3313
# listing_status          3263
# instant_bookable        2896
# guests                  2731
# property_type           2268
# last_review             2000
# price                   1992
# beds                    1639
# reviews_per_month       1600
# rating                  1000
# neighbourhood              0
# host_id                    0
# listing_id                 0
# room_type                  0
# number_of_reviews          0
# minimum_nights             0
# city                       0
# host_since                 0
# availability_365           0
# latitude                   0
# longitude                  0
# cancellation_policy        0
# dtype: int64

# %%
Cleaned_df['guests'] = (
    Cleaned_df['guests']
    .astype(str)
    .str.replace('%','',regex=False)
)
Cleaned_df['guests'] = pd.to_numeric(Cleaned_df['guests'],errors = 'coerce')

# %%
Cleaned_df['bathrooms'] = pd.to_numeric(
    Cleaned_df['bathrooms'],errors = 'coerce'
)

# %%
Cleaned_df['price'] = pd.to_numeric(
    Cleaned_df['price'],errors = 'coerce'
)

# %%
numeric_columns = [
    'price',
    'reviews_per_month',
    'rating',
    'beds',
    'bedrooms',
    'bathrooms',
    'guests',
    'host_response_rate'
]
for col in numeric_columns:
    Cleaned_df[col] = Cleaned_df[col].fillna(Cleaned_df[col].median())

# %%
categorical_columns = [
    'neighbourhood',
    'city',
    'room_type',
    'instant_bookable',
    'cancellation_policy',
    'listing_status',
    'device',
    'payment_method'
]
for col in categorical_columns:
    Cleaned_df[col] = Cleaned_df[col].fillna(Cleaned_df[col].mode()[0])

# %%
Cleaned_df['host_name'] = Cleaned_df['host_name'].fillna('unknown')

# %%
Cleaned_df['last_review'] = pd.to_datetime(Cleaned_df['last_review'],errors = 'coerce')

# %%
Cleaned_df.isnull().sum().sort_values(ascending = False)
# Out:
# property_type          2268
# last_review            2000
# host_id                   0
# host_name                 0
# neighbourhood             0
# city                      0
# room_type                 0
# price                     0
# minimum_nights            0
# number_of_reviews         0
# listing_id                0
# reviews_per_month         0
# availability_365          0
# longitude                 0
# latitude                  0
# host_since                0
# rating                    0
# beds                      0
# bedrooms                  0
# bathrooms                 0
# guests                    0
# instant_bookable          0
# cancellation_policy       0
# host_response_rate        0
# listing_status            0
# device                    0
# payment_method            0
# dtype: int64

# %%
Cleaned_df[Cleaned_df['price'] <= 0]
# Out:
#        listing_id  host_id host_name  neighbourhood           city  \
# 656        110049     9887      Emma  staten island       new york
# 11726      117013     9431     David      manhattan       new york
# 13931      117745     9777   Michael  staten island  new york city
# 17572      116289     8008   Michael  staten island       new york
# 20007      117869     7521   unknown         queens            nyc
#
#              room_type property_type  price  minimum_nights  \
# 656       private room         condo  -50.0               7
# 11726  entire home/apt     apartment  -50.0              14
# 13931     private room         house  -50.0               1
# 17572  entire home/apt           NaN  -50.0              20
# 20007  entire home/apt         condo  -50.0              21
#
#        number_of_reviews  reviews_per_month  availability_365   latitude  \
# 656                   42               3.43               323  40.795671
# ...

# %%
Cleaned_df = Cleaned_df[Cleaned_df['price']>0]

# %%
Cleaned_df[Cleaned_df['minimum_nights'] <= 0]
# Out:
# Empty DataFrame
# Columns: [listing_id, host_id, host_name, neighbourhood, city, room_type, property_type, price, minimum_nights, number_of_reviews, reviews_per_month, availability_365, latitude, longitude, host_since, last_review, rating, beds, bedrooms, bathrooms, guests, instant_bookable, cancellation_policy, host_response_rate, listing_status, device, payment_method]
# Index: []

# %%
Cleaned_df[(Cleaned_df['rating']<0) |(Cleaned_df['rating']>5)]
# Out:
# Empty DataFrame
# Columns: [listing_id, host_id, host_name, neighbourhood, city, room_type, property_type, price, minimum_nights, number_of_reviews, reviews_per_month, availability_365, latitude, longitude, host_since, last_review, rating, beds, bedrooms, bathrooms, guests, instant_bookable, cancellation_policy, host_response_rate, listing_status, device, payment_method]
# Index: []

# %%
Cleaned_df.dtypes
# Out:
# listing_id                      int64
# host_id                         int64
# host_name                         str
# neighbourhood                     str
# city                              str
# room_type                         str
# property_type                     str
# price                         float64
# minimum_nights                  int64
# number_of_reviews               int64
# reviews_per_month             float64
# availability_365                int64
# latitude                      float64
# longitude                     float64
# host_since             datetime64[us]
# last_review            datetime64[us]
# rating                        float64
# beds                          float64
# bedrooms                      float64
# bathrooms                     float64
# guests                        float64
# instant_bookable                  str
# cancellation_policy               str
# host_response_rate            float64
# listing_status                    str
# ...

# %%
'duplicate row:',Cleaned_df.duplicated().sum()
# Out:
# ('duplicate row:', np.int64(0))

# %%
Cleaned_df.isnull().sum()
# Out:
# listing_id                0
# host_id                   0
# host_name                 0
# neighbourhood             0
# city                      0
# room_type                 0
# property_type          2267
# price                     0
# minimum_nights            0
# number_of_reviews         0
# reviews_per_month         0
# availability_365          0
# latitude                  0
# longitude                 0
# host_since                0
# last_review            2000
# rating                    0
# beds                      0
# bedrooms                  0
# bathrooms                 0
# guests                    0
# instant_bookable          0
# cancellation_policy       0
# host_response_rate        0
# listing_status            0
# device                    0
# payment_method            0
# dtype: int64

# %%
Cleaned_df['property_type'].value_counts(dropna = False)
# Out:
# property_type
# apartment      4534
# house          4428
# NaN            2267
# loft           2235
# condo          2230
# guest suite    2154
# townhouse      2147
# Name: count, dtype: int64

# %%
Cleaned_df['property_type'].unique()
# Out:
# <StringArray>
# ['apartment', 'guest suite', nan, 'loft', 'townhouse', 'house', 'condo']
# Length: 7, dtype: str

# %%
Cleaned_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
Cleaned_df = Cleaned_df.drop_duplicates()

# %%
Cleaned_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
Cleaned_df.head()
# Out:
#    listing_id  host_id host_name  neighbourhood           city  \
# 0      107345    10276   unknown          bronx  new york city
# 1      109454     5049      Emma      manhattan            nyc
# 2      119857    11567    Sophia      manhattan            nyc
# 3      108591     5546   unknown         queens            nyc
# 4      117164     8693   Michael  staten island       new york
#
#          room_type property_type   price  minimum_nights  number_of_reviews  \
# 0       hotel room     apartment  213.62              27                 51
# 1     private room   guest suite  289.00              15                 38
# 2     private room           NaN  130.82              24                 39
# 3  entire home/apt     apartment   36.43              13                 49
# 4  entire home/apt          loft  271.74              21                 41
#
#    reviews_per_month  availability_365   latitude  longitude host_since  \
# ...

# %%
Cleaned_df.tail()
# Out:
#        listing_id  host_id   host_name  neighbourhood      city  \
# 20115      111285    11257      Sophia       brooklyn  new york
# 20116      111965     8929       David          bronx  new york
# 20117      105391    10739     Michael  staten island  new york
# 20118      100861     8325  John Smith       brooklyn       nyc
# 20119      115796     5659     unknown         queens       nyc
#
#              room_type property_type   price  minimum_nights  \
# 20115      shared room     townhouse   68.76             365
# 20116     private room   guest suite   69.01              19
# 20117  entire home/apt     apartment  280.07              12
# 20118      shared room           NaN  476.49             365
# 20119     private room     townhouse   84.16            3650
#
#        number_of_reviews  reviews_per_month  availability_365   latitude  \
# 20115                 44               2.73               286  40.651466
# ...

# %%
print('Rows:',Cleaned_df.shape[0])
print('columns:',Cleaned_df.shape[1])
print(Cleaned_df.head())
print(Cleaned_df.info())
# Out:
# Rows: 19995
# columns: 27
#    listing_id  host_id host_name  neighbourhood           city  \
# 0      107345    10276   unknown          bronx  new york city
# 1      109454     5049      Emma      manhattan            nyc
# 2      119857    11567    Sophia      manhattan            nyc
# 3      108591     5546   unknown         queens            nyc
# 4      117164     8693   Michael  staten island       new york
#
#          room_type property_type   price  minimum_nights  number_of_reviews  \
# 0       hotel room     apartment  213.62              27                 51
# 1     private room   guest suite  289.00              15                 38
# 2     private room           NaN  130.82              24                 39
# 3  entire home/apt     apartment   36.43              13                 49
# 4  entire home/apt          loft  271.74              21                 41
#
#    reviews_per_month  availability_365   latitude  longitude host_since  \
# ...

# %%
Cleaned_df['property_type'] = Cleaned_df['property_type'].fillna('unknown')

# %%
Cleaned_df.head()
# Out:
#    listing_id  host_id host_name  neighbourhood           city  \
# 0      107345    10276   unknown          bronx  new york city
# 1      109454     5049      Emma      manhattan            nyc
# 2      119857    11567    Sophia      manhattan            nyc
# 3      108591     5546   unknown         queens            nyc
# 4      117164     8693   Michael  staten island       new york
#
#          room_type property_type   price  minimum_nights  number_of_reviews  \
# 0       hotel room     apartment  213.62              27                 51
# 1     private room   guest suite  289.00              15                 38
# 2     private room       unknown  130.82              24                 39
# 3  entire home/apt     apartment   36.43              13                 49
# 4  entire home/apt          loft  271.74              21                 41
#
#    reviews_per_month  availability_365   latitude  longitude host_since  \
# ...

# %%
Cleaned_df.loc[Cleaned_df['bedrooms']<0,'bedrooms'] = Cleaned_df['bedrooms'].median()

# %%
Cleaned_df.head()
# Out:
#    listing_id  host_id host_name  neighbourhood           city  \
# 0      107345    10276   unknown          bronx  new york city
# 1      109454     5049      Emma      manhattan            nyc
# 2      119857    11567    Sophia      manhattan            nyc
# 3      108591     5546   unknown         queens            nyc
# 4      117164     8693   Michael  staten island       new york
#
#          room_type property_type   price  minimum_nights  number_of_reviews  \
# 0       hotel room     apartment  213.62              27                 51
# 1     private room   guest suite  289.00              15                 38
# 2     private room       unknown  130.82              24                 39
# 3  entire home/apt     apartment   36.43              13                 49
# 4  entire home/apt          loft  271.74              21                 41
#
#    reviews_per_month  availability_365   latitude  longitude host_since  \
# ...

# %%
Cleaned_df['bedrooms'].median()
# Out:
# np.float64(3.0)

# %%
Cleaned_df['city'] = Cleaned_df['city'].str.lower().str.strip()
Cleaned_df['city'] = Cleaned_df['city'].replace({
    'nyc':'new york',
    'new york city':'new york'
})

# %%
Cleaned_df['city'].unique()
# Out:
# <StringArray>
# ['new york']
# Length: 1, dtype: str

# %%
Cleaned_df.loc[Cleaned_df['beds']<0,'beds'] = Cleaned_df['beds'].median()

# %%
print('Rows:',Cleaned_df.shape[0])
print('columns:',Cleaned_df.shape[1])
print(Cleaned_df.head())
print(Cleaned_df.info())
# Out:
# Rows: 19995
# columns: 27
#    listing_id  host_id host_name  neighbourhood      city        room_type  \
# 0      107345    10276   unknown          bronx  new york       hotel room
# 1      109454     5049      Emma      manhattan  new york     private room
# 2      119857    11567    Sophia      manhattan  new york     private room
# 3      108591     5546   unknown         queens  new york  entire home/apt
# 4      117164     8693   Michael  staten island  new york  entire home/apt
#
#   property_type   price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0     apartment  213.62              27                 51               1.38
# 1   guest suite  289.00              15                 38               0.22
# 2       unknown  130.82              24                 39               3.76
# 3     apartment   36.43              13                 49              10.15
# 4          loft  271.74              21                 41               1.67
#
# ...

# %%
Cleaned_df.isnull().sum()
# Out:
# listing_id                0
# host_id                   0
# host_name                 0
# neighbourhood             0
# city                      0
# room_type                 0
# property_type             0
# price                     0
# minimum_nights            0
# number_of_reviews         0
# reviews_per_month         0
# availability_365          0
# latitude                  0
# longitude                 0
# host_since                0
# last_review            2000
# rating                    0
# beds                      0
# bedrooms                  0
# bathrooms                 0
# guests                    0
# instant_bookable          0
# cancellation_policy       0
# host_response_rate        0
# listing_status            0
# device                    0
# payment_method            0
# dtype: int64

# %%
Cleaned_df.to_csv(
    'airbnb_cleaned.csv',
    index = False
)
